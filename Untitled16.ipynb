# %% [markdown]
# <a href="https://colab.research.google.com/github/zeliasporto/daic-woz/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/adbailey1/daic_woz_process.git
# Out:
# Cloning into 'daic_woz_process'...
# remote: Enumerating objects: 171, done.
# remote: Counting objects: 100% (171/171), done.
# remote: Compressing objects: 100% (141/141), done.
# remote: Total 171 (delta 87), reused 92 (delta 26), pack-reused 0 (from 0)
# Receiving objects: 100% (171/171), 97.88 KiB | 1.53 MiB/s, done.
# Resolving deltas: 100% (87/87), done.

# %%
# %cd daic_woz_process
# Out:
# /content/daic_woz_process

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# !mamba env update -n base -f environment.yml
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:13
# 🔁 Restarting kernel...
# Channels:
#  - pytorch
#  - conda-forge
#  - anaconda
#  - defaults
# Platform: linux-64
# done
# failed
#
# SpecsConfigurationConflictError: Requested specs conflict with configured specs.
#   requested specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.2.0=py37_0
#     - attrs==19.3.0=py_0
#     - audioread==2.1.6=py37_0
#     - blas==1.0=mkl
#     - boto==2.49.0=py37_0
#     - boto3==1.12.39=py_0
#     - botocore==1.15.39=py_0
#     - bzip2==1.0.8=h7b6447c_0
#     - ca-certificates==2020.4.5.1=hecc5488_0
#     - cachetools==3.1.1=py_0
#     - cairo==1.14.12=h8948797_3
#     - certifi==2020.4.5.1=py37hc8dfbb8_0
#     - cffi==1.13.2=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
# ...

# %%
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Substitua pelo caminho real da pasta
features_dir = '/content/drive/MyDrive/DAIC-WOZ_Data/full_test_split.csv'

if os.path.exists(features_dir):
    print(f"A pasta '{features_dir}' existe.")
else:
    print(f"A pasta '{features_dir}' não existe.")

transcripts = 'https://drive.google.com/drive/folders/1K46RFwIFHZLUGY-8gfvtphA7O3SIlvoq?usp=drive_link'
# Out:
# Mounted at /content/drive
# A pasta '/content/drive/MyDrive/DAIC-WOZ_Data/full_test_split.csv' existe.

# %%
# !pip install numpy h5py pandas torch librosa natsort tqdm matplotlib psutil gensim ipykernel
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 58.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 92.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 29.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 44.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 128.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 148.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 31.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 68.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 60.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 63.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 66.4 MB/s eta 0:00:00
# ...

# %%
# %cd daic_woz_process
# Out:
# /content/daic_woz_process

# %%
# !python -m run
# Out:
# A directory at this location exists, do you want to delete? y
# Processing Audio Files
#
# iterator is 0, and filename is /content/drive/MyDrive/DAIC-WOZ_Data/300_P/300_AUDIO.wav
# iterator is 1, and filename is /content/drive/MyDrive/DAIC-WOZ_Data/301_P/301_AUDIO.wav
# iterator is 2, and filename is /content/drive/MyDrive/DAIC-WOZ_Data/302_P/302_AUDIO.wav
# iterator is 3, and filename is /content/drive/MyDrive/DAIC-WOZ_Data/303_P/303_AUDIO.wav
# iterator is 4, and filename is /content/drive/MyDrive/DAIC-WOZ_Data/304_P/304_AUDIO.wav
# iterator is 5, and filename is /content/drive/MyDrive/DAIC-WOZ_Data/305_P/305_AUDIO.wav
# iterator is 6, and filename is /content/drive/MyDrive/DAIC-WOZ_Data/306_P/306_AUDIO.wav
# iterator is 7, and filename is /content/drive/MyDrive/DAIC-WOZ_Data/307_P/307_AUDIO.wav
# iterator is 8, and filename is /content/drive/MyDrive/DAIC-WOZ_Data/308_P/308_AUDIO.wav
# iterator is 9, and filename is /content/drive/MyDrive/DAIC-WOZ_Data/309_P/309_AUDIO.wav
# ...

# %%
# !pip install ipykernel

# %%
import mimetypes

filename = "/content/drive/MyDrive/DAIC-WOZ_Data/431_P/431_AUDIO.wav"
mime_type, _ = mimetypes.guess_type(filename)

print(f"Tipo de arquivo detectado: {mime_type}")
# Out:
# Tipo de arquivo detectado: audio/x-wav

# %%
# !pip install pydub
# !apt-get install ffmpeg
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.

# %%
from pydub import AudioSegment
import os

def convert_to_standard_wav(input_path):
    """Converte um arquivo de áudio para um WAV compatível"""
    output_path = input_path.replace(".wav", "_converted.wav")

    try:
        audio = AudioSegment.from_file(input_path)
        audio = audio.set_frame_rate(16000).set_channels(1)  # Ajuste para 16kHz mono (compatível com ASR/NLP)
        audio.export(output_path, format="wav")
        print(f"Arquivo convertido e salvo em: {output_path}")
        return output_path
    except Exception as e:
        print(f"Erro ao converter {input_path}: {e}")
        return None

# Caminho do arquivo original
input_file = "/content/drive/MyDrive/DAIC-WOZ_Data/431_P/431_AUDIO.wav"

# Converter para WAV padrão
converted_file = convert_to_standard_wav(input_file)

if converted_file:
    print("Conversão concluída. Agora o arquivo pode ser lido com `librosa` ou `scipy`.")
else:
    print("Falha na conversão. Verifique o arquivo original.")
# Out:
# Erro ao converter /content/drive/MyDrive/DAIC-WOZ_Data/431_P/431_AUDIO.wav: [Errno 2] No such file or directory: '/content/drive/MyDrive/DAIC-WOZ_Data/431_P/431_AUDIO.wav'
# Falha na conversão. Verifique o arquivo original.

# %%
# !ffmpeg -i "/content/drive/MyDrive/DAIC-WOZ_Data/431_P/431_AUDIO.wav"
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
import shutil
dir_name = '/content/daic_woz_process/features'
output_filename = 'features_raw'
shutil.make_archive(output_filename, 'zip', dir_name)
# Out:
# '/content/daic_woz_process/features_raw.zip'

# %%
shutil.move("/content/daic_woz_process/features_raw.zip", "/content/drive/MyDrive/features_raw.zip")

print("Arquivo ZIP salvo no Drive! ✅")
# Out:
# Arquivo ZIP salvo no Drive! ✅
